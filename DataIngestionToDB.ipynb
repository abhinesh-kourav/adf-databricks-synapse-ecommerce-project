# %%
hostname = "sql12.freemysqlhosting.net"
database = "sql12755141"
port = "3306"
username = "sql12755141"
password = "qHcRIlnm9l"

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/mayank953/BigDataProjects/refs/heads/main/Project-Brazillian%20Ecommerce/Data/olist_order_payments_dataset.csv"
payments = pd.read_csv(url)
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
# !pip install sqlalchemy
# !pip install pymysql  # If you're using MySQL
from sqlalchemy import create_engine

# %%
sql_str = f"mysql+pymysql://{username}:{password}@{hostname}:{port}/{database}"
#sql_str = r"mysql+pymysql://avnadmin:AVNS_tdEinc3AsrR60Sl6l4q@mysql-377ad157-olistdata.g.aivencloud.com:22824/defaultdb?ssl=true"
engine = create_engine(sql_str)

# %%
payments.to_sql('olist_order_payments', con=engine, if_exists='replace', index=False)
# Out:
# 103886

# %%
# Read data back from the database
result = pd.read_sql('SELECT * FROM olist_order_payments', con=engine)
print(result)
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
result.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
translation_df = pd.read_csv(r"https://raw.githubusercontent.com/mayank953/BigDataProjects/refs/heads/main/Project-Brazillian%20Ecommerce/Data/product_category_name_translation.csv")
translation_df
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 28.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 15.2 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://olistNoSQL_setseasily:88d397952c6bca90bc45dc974b318e03eda6ef96@rhdgs.h.filess.io:27018/olistNoSQL_setseasily")  # Replace with your connection string
db = client["olistNoSQL_setseasily"]  # Replace with your database name
collection = db["translation"]  # Replace with your collection name

# Insert DataFrame into MongoDB
collection.insert_many(translation_df.to_dict("records"))
# Out:
# InsertManyResult([ObjectId('6775771e3a43751cb0ce6666'), ObjectId('6775771e3a43751cb0ce6667'), ObjectId('6775771e3a43751cb0ce6668'), ObjectId('6775771e3a43751cb0ce6669'), ObjectId('6775771e3a43751cb0ce666a'), ObjectId('6775771e3a43751cb0ce666b'), ObjectId('6775771e3a43751cb0ce666c'), ObjectId('6775771e3a43751cb0ce666d'), ObjectId('6775771e3a43751cb0ce666e'), ObjectId('6775771e3a43751cb0ce666f'), ObjectId('6775771e3a43751cb0ce6670'), ObjectId('6775771e3a43751cb0ce6671'), ObjectId('6775771e3a43751cb0ce6672'), ObjectId('6775771e3a43751cb0ce6673'), ObjectId('6775771e3a43751cb0ce6674'), ObjectId('6775771e3a43751cb0ce6675'), ObjectId('6775771e3a43751cb0ce6676'), ObjectId('6775771e3a43751cb0ce6677'), ObjectId('6775771e3a43751cb0ce6678'), ObjectId('6775771e3a43751cb0ce6679'), ObjectId('6775771e3a43751cb0ce667a'), ObjectId('6775771e3a43751cb0ce667b'), ObjectId('6775771e3a43751cb0ce667c'), ObjectId('6775771e3a43751cb0ce667d'), ObjectId('6775771e3a43751cb0ce667e'), ObjectId('6775771e3a43751cb0ce
# ...
